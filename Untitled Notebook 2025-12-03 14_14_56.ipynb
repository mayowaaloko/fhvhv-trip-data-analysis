-- %%
SELECT COUNT(*) AS total_trips
FROM workspace.default.nyc_ridehail_q1_2025_with_geography;

-- %%
SELECT SUM(base_passenger_fare) AS total_revenue
FROM workspace.default.nyc_ridehail_q1_2025_with_geography;
